# %%
import layoutparser as lp
import layoutparser.io

# %%
pdf_layout = lp.load_pdf("data/pdf/cv.pdf")
pdf_layout[0] # the layout for page 0
pdf_layout, pdf_images = lp.load_pdf("data/pdf/cv.pdf", load_images=True)
lp.draw_box(pdf_images[0], pdf_layout[0])
# Out:
# <PIL.Image.Image image mode=RGB size=612x792>

# %%
model = lp.models.Detectron2LayoutModel('lp://HJDataset/faster_rcnn_R_50_FPN_3x/config')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/0g/8cm9dpv57cbbpvxymjj_16f00000gn/T/ipykernel_79372/219111246.py in <cell line: 1>()
# ----> 1 model = lp.models.Detectron2LayoutModel('lp://HJDataset/faster_rcnn_R_50_FPN_3x/config')
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/layoutparser/models/base_layoutmodel.py in __new__(cls, *args, **kwargs)
#      85     def __new__(cls, *args, **kwargs):
#      86
# ---> 87         requires_backends(cls, cls.DEPENDENCIES)
#      88         return super().__new__(cls)
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/layoutparser/file_utils.py in requires_backends(obj, backends)
#     173     name = obj.__name__ if hasattr(obj, "__name__") else obj.__class__.__name__
#     174     if not all(BACKENDS_MAPPING[backend][0]() for backend in backends):
# ...
